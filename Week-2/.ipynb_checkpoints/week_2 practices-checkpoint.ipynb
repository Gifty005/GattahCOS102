# %%
str = input("Enter your state of origin:")

print ("Your state of origin is: ", str)
print ("The first character is: ", str[0])
print ("The character starting from 3rd to the 5th are: ", str[2:5])
print ("The string starting from 3rd character is: ", str[2:])
print ("State of origin two times", str * 2)
# Out:
# Enter your state of origin: kogi
# Your state of origin is:  kogi
# The first character is:  k
# The character starting from 3rd to the 5th are:  gi
# The string starting from 3rd character is:  gi
# State of origin two times kogikogi

# %%
#input from user
m = float(input("Enter mass in kilograms: "))

# constant value for the speed of light in m/s
c = 299792458

#calculating energy using einstein's equation 
energy = m * c ** 2

#Displaying the result 
print (f"The energy equivalent to {m} kg of mass is {energy} joules.")
# Out:
# Enter mass in kilograms:  086
# The energy equivalent to 86.0 kg of mass is 7.729294537136632e+18 joules.

# %%
list = ['Anaconda', 675, 2.34, 'Jupyter', 90.3]
shortlist = [321, 'python']

print(list)             #prints complete list 
print(list[0])          #print first element of the list
print(list[1:3])        #prints elements starting from 2nd to 3rd
print(list[2:])         #prints elements starting from the 3rd element '''
print(shortlist * 2)    #prints list two times
print(list + shortlist) #prints concatenated lists
# Out:
# ['Anaconda', 675, 2.34, 'Jupyter', 90.3]
# Anaconda
# [675, 2.34]
# [2.34, 'Jupyter', 90.3]
# [321, 'python', 321, 'python']
# ['Anaconda', 675, 2.34, 'Jupyter', 90.3, 321, 'python']

# %%
tuple = ("Ekiti", 750, 'Oshogbo', 250, 'Akure', 500)
s_tuple = ("Abeokuta", 300,"ogbomoso")

#print the complete tuple 
print (tuple)

#print last element of the tuple
print (tuple [-1])

#print elements of the tuple starting from 2nd to 3rd
print (tuple [2:4])

#print element of the tuple starting from 3rd element
print(tuple [3:])

#prints the content of the tuple thrice
print(s_tuple * 3)

#print concatenated tuples
print (tuple + s_tuple)
# Out:
# ('Ekiti', 750, 'Oshogbo', 250, 'Akure', 500)
# 500
# ('Oshogbo', 250)
# (250, 'Akure', 500)
# ('Abeokuta', 300, 'ogbomoso', 'Abeokuta', 300, 'ogbomoso', 'Abeokuta', 300, 'ogbomoso')
# ('Ekiti', 750, 'Oshogbo', 250, 'Akure', 500, 'Abeokuta', 300, 'ogbomoso')

# %%
#Returns false as game_1 is not equal to game_2
game_1 = 2
game_2 = 4
print(bool(game_1 == game_2))
#or
print (game_1 == game_2)

#Returns False as  val is none 
val = None
print (bool(val))

#Returns false as num is an empty sequence 
num = ()
print (bool(num))

#Returns true as age is boolen
age = True
print (bool (age))
# Out:
# False
# False
# False
# False
# True

# %%
#convert to int

grade = int (70) #grade will be 70
gpa = int (4.9)  #grade will be 4.9
cgpa = int ("4")  #cgpa will be 4

print (f"Grade = {grade}")
print (f"GPA = {gpa}")
print (f"CGPA = {cgpa}")
# Out:
# Grade = 70
# GPA = 4
# CGPA = 4

# %%
#convert to float

grade =float(97)
gpa = float (5)
cgpa= float("4.7")

print(f"Grade = {grade}")
print(f"GPA = {gpa}")
print(f"CGPA = {cgpa}")
# Out:
# Grade = 97.0
# GPA = 5.0
# CGPA = 4.7

# %% [markdown]
# PRACTICE 2

# %%
#python program to swap cities

#To take a temporary variable and swap the cities 
city_1 = input('Enter the name of city 1: ')
city_2 = input('Enter name of the c ity 2: ')

#create a temporary variable and swap the cities
temp = city_1
city_1 = city_2
city_2 = temp

print (f"The name of city 1 after swapping is {city_1} ")
print (f"The name of city 2 after swapping is {city_2} ")
# Out:
# Enter the name of city 1:  kogi
# Enter name of the c ity 2:  lagos
# The name of city 1 after swapping is lagos
# The name of city 2 after swapping is kogi

# %%
#program to check if a number is positive ,negative or zero
num = float(input("Enter a number : "))
if num > 0 :
    print("positive number")
elif num== 0:
    print("Zero")
else:
    print("Negative number")
# Out:
# Enter a number :  3
# positive number
