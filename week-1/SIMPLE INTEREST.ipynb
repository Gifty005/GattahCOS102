# %%
print ("SIMPLE INTEREST CALCULATOR")
P = float(input("Enter principal amount(p):"))
R = float(input("Enter Rate of interest(R% per year):"))
T = float(input("Enter Time period(T in years): "))

#calculate simple interest
A = P * (1 + (R/100)*T)
#Display results
print("final amount(A):", A )
SI = A - P
print ("simple interest(SI):", SI)
# Out:
# SIMPLE INTEREST CALCULATOR
# Enter principal amount(p): 2
# Enter Rate of interest(R% per year): 5
# Enter Time period(T in years):  2
# final amount(A): 2.2
# simple interest(SI): 0.20000000000000018

# %% [markdown]
# ![SIMPLE INTEREST FLOW CHART DIAGRAM.jpg](attachment:52ce2a52-01a6-4cf5-84d9-9716001ba6a4.jpg)
