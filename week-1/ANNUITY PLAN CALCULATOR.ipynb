# %%
PMT = float (input("Enter payment each(PMT):"))
r = float (input ("Enter interest \ rate(%):"))/100
t = int(input ("Enter number of periods (t):"))
A = PMT* ((1 + r) ** t -1)/r
print ("future value of the annuity = ",A)
# Out:
# Enter payment each(PMT): 1000.00
# Enter interest \ rate(%): 5.0
# Enter number of periods (t): 3
# future value of the annuity =  3152.5000000000023

# %% [markdown]
# "C:\Users\New\Downloads\ANNUITY PLAN FLOW CHART DIAGRAM.jpg"

# %% [markdown]
# "C:\Users\New\Downloads\ANNUITY PLAN FLOW CHART DIAGRAM.jpg"

# %% [markdown]
# ![ANNUITY PLAN FLOW CHART DIAGRAM.jpg](attachment:0e3dba6a-686e-4aec-87c9-7898fc3360cc.jpg)
