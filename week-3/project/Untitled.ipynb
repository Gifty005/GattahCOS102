# %%
import tkinter as tk
from tkinter import messagebbox as msgbox
def submit():
    username_entry.get()
    password_entry.get()

    window.mainloop()
    window= tk.Toplevel(root)
ulabel = tk.Label(window, text = 'Username')
ulabel = tk.Label.pack()
uentry = tk.Entry(window)
uentry.pack
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 import tkinter as tk
# ----> 2 from tkinter import messagebbox as msgbox
#       3 def submit():
#       4     username_entry.get()
#
# ImportError: cannot import name 'messagebbox' from 'tkinter' (C:\Users\New\anaconda3\Lib\tkinter\__init__.py)

# %%
import pandas as pd
df = pd.read_csv('GIG-logistics(in).csv')

# %%
df
# Out:
#    EmployeeID                Name        Department  \
# 0      GIG001  Chukwuemeka Okafor        Operations
# 1      GIG002        Adaeze Nwosu        Operations
# 2      GIG003       Tunde Adeleke        Operations
# 3      GIG004           Ngozi Eze        Operations
# 4      GIG005        Emeka Chukwu        Operations
# 5      GIG006        Fatima Bello        Operations
# 6      GIG007       Seun Adesanya        Operations
# 7      GIG008   Kelechi Onyekachi        Operations
# 8      GIG009          Hauwa Musa           Finance
# 9      GIG010      Rotimi Adeyemi           Finance
# 10     GIG011          Chioma Obi           Finance
# 11     GIG012         Yusuf Garba           Finance
# 12     GIG013      Blessing Okoro           Finance
# 13     GIG014      Taiwo Akinwale           Finance
# 14     GIG015         Amina Usman   Human Resources
# 15     GIG016     Ifeanyi Okonkwo   Human Resources
# 16     GIG017        Sade Fashola   Human Resources
# ...

# %%
df_useful = df[['Name', 'Department']]
df_useful
# Out:
#                   Name        Department
# 0   Chukwuemeka Okafor        Operations
# 1         Adaeze Nwosu        Operations
# 2        Tunde Adeleke        Operations
# 3            Ngozi Eze        Operations
# 4         Emeka Chukwu        Operations
# 5         Fatima Bello        Operations
# 6        Seun Adesanya        Operations
# 7    Kelechi Onyekachi        Operations
# 8           Hauwa Musa           Finance
# 9       Rotimi Adeyemi           Finance
# 10          Chioma Obi           Finance
# 11         Yusuf Garba           Finance
# 12      Blessing Okoro           Finance
# 13      Taiwo Akinwale           Finance
# 14         Amina Usman   Human Resources
# 15     Ifeanyi Okonkwo   Human Resources
# 16        Sade Fashola   Human Resources
# 17        Nnamdi Okeke   Human Resources
# 18    Maryam Abdullahi   Human Resources
# 19   Oluwaseun Balogun        Technology
# 20     Chidi Nwachukwu        Technology
# 21         Aisha Lawal        Technology
# ...

# %%
df_useful=df[['Role', 'Email', 'Phone']]
df_useful
# Out:
#                              Role                         Email       Phone
# 0              Operations Manager     c.okafor@giglogistics.com  8031234567
# 1                Dispatch Officer      a.nwosu@giglogistics.com  8031234568
# 2           Logistics Coordinator    t.adeleke@giglogistics.com  8031234569
# 3                Fleet Supervisor        n.eze@giglogistics.com  8031234570
# 4                   Route Planner     e.chukwu@giglogistics.com  8031234571
# 5               Warehouse Officer      f.bello@giglogistics.com  8031234572
# 6                  Delivery Agent   s.adesanya@giglogistics.com  8031234573
# 7                  Delivery Agent  k.onyekachi@giglogistics.com  8031234574
# 8           Chief Finance Officer       h.musa@giglogistics.com  8031234575
# 9                      Accountant    r.adeyemi@giglogistics.com  8031234576
# 10                 Budget Analyst        c.obi@giglogistics.com  8031234577
# ...
