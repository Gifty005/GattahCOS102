# %%
#calling a function
def printme (str):
    #This is a print function
    print(str)
    return;
printme("I'm the first call user defined function!");
printme("Again second call to the same function");
# Out:
# I'm the first call user defined function!
# Again second call to the same function

# %%
#passing by value vs reference
def changeme(mylist):
    #This changes a passed list
    mylist=[1,2,3,4]
    print("values inside my function is:",  mylist)
    return
mylist=[10,20,30];
changeme(mylist);
print("values inside my function is:", mylist)
# Out:
# values inside my function is: [1, 2, 3, 4]
# values inside my function is: [10, 20, 30]

# %%
def printme(str):
    #This prints a passed string
    print(str)
    return;
printme()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       3     print(str)
#       4     return;
# ----> 5 printme()
#
# TypeError: printme() missing 1 required positional argument: 'str'

# %%
def printme(str):
    #This prints a passed value
    print(str);
    return;
printme(str = "my string");
# Out:
# my string

# %%
def printinfo (name,age):
    #test function
    
    print("Name: ", name)
    print("Age: ", age)
    return
printinfo(age=50,name = "miki");
# Out:
# Name:  miki
# Age:  50

# %%
def printinfo (name,age= 35):
    #test function
    
    print("Name: ", name)
    print("Age: ", age)
    return
printinfo( age=50,name = "miki");
printinfo( name = "miki")
# Out:
# Name:  miki
# Age:  50
# Name:  miki
# Age:  35

# %%
def printinfo (arg1, *vartuple):
    #This is a test
    print ("output is: ")
    print (arg1)
    for var in vartuple:
        print (var)
    return;
printinfo(10);
printinfo(70,60,50);
# Out:
# output is:
# 10
# output is:
# 70
# 60
# 50

# %%
total = 50 #This is a global variable
def sum(arg1, arg2):
#add both parameters
 total = arg1 + arg2
 print("Inside the function local total: ", total)
 return total;
# Now you can call sum function
sum(10,20)
print ("outside the global function: ", total)
# Out:
# Inside the function local total:  30
# outside the global function:  50

# %%
def swap (x, y):
    global a
    a ="Lawal"
    x,y = y,x
    b = "Chris"
    b= "Edward"
    c="Lola"
    print(a,b,x,y)
    a = "Mary"
swap("Tina","Tolu")
print(a)
# Out:
# Lawal Edward Tolu Tina
# Mary
